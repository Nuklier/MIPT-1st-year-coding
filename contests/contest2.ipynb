# %%
# merge sort implementation
def merge(arr, l, m, r):
    L = arr[l : m + 1]
    R = arr[m + 1 : r + 1]
    n1, n2 = len(L), len(R)
    i, j = 0, 0
    k = l
    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
    if n1 < n2:
        len_i = n2
        list_i = R
        idx_i = j
    else:
        len_i = n1
        list_i = L
        idx_i = i
    while idx_i < len_i:
        arr[k] = list_i[idx_i]
        idx_i += 1
        k += 1


def msort(arr, l, r):
    if l < r:
        m = l + (r - l) // 2
        msort(arr, l, m)
        msort(arr, m + 1, r)
        merge(arr, l, m, r)

# эту штуку вставляем в каждую задачу, изменив под задачу
# Out:
# [1, 2, 3, 4]

# %%
# 1
def numbers(a):
    r = []
    while a > 0:
        r.append(a % 10)
        a //= 10
    return r


def degroot(a):
    while a > 9:
        ns = numbers(a)
        t = 0
        for i in ns:
            t += i
        a = t
    return a


def merge(arr, l, m, r):
    L = arr[l : m + 1]
    R = arr[m + 1 : r + 1]
    n1, n2 = len(L), len(R)
    i, j = 0, 0
    k = l
    while i < n1 and j < n2:
        if degroot(L[i]) < degroot(R[j]):
            arr[k] = L[i]
            i += 1
        elif degroot(L[i]) > degroot(R[j]):
            arr[k] = R[j]
            j += 1
        elif L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
    if n1 < n2:
        len_i = n2
        list_i = R
        idx_i = j
    else:
        len_i = n1
        list_i = L
        idx_i = i
    while idx_i < len_i:
        arr[k] = list_i[idx_i]
        idx_i += 1
        k += 1


def msort(arr, l, r):
    if l < r:
        m = l + (r - l) // 2
        msort(arr, l, m)
        msort(arr, m + 1, r)
        merge(arr, l, m, r)

a = list(map(int, input().split()))
msort(a, 0, len(a) - 1)
print(" ".join(str(i) for i in a))
print()
# Out:
# 1 46 2 40 23 17 98

# %%
# 2
a = list(map(int, input().split()))
mx = [0] * (len(a)) # массив минимумов
c = [0] * (len(a)) # массив ответа
m = a[0] # минимум
c[0] = -1
mx[0] = m
for i in range(1, len(a)):
    if a[i] > m:
        m = a[i]
        c[i] = -1
    else:
        k = i - 1
        while a[i] > a[k]:
            k -= 1
        c[i] = k
    mx[i] = m
print(" ".join(str(i) for i in c))
# Out:
# -1 0 1 0 -1 4 4 6 7 7 7 4 4 12 12 12 12

# %%
# 3
# просто сортнуть, потом смотреть на количество разных для каждого
# написал криво, но я поймешь

# лол сорт походу не нужен вообще
# ответ за 12 строк  забит в контест

def merge(arr, l, m, r):
    L = arr[l : m + 1]
    R = arr[m + 1 : r + 1]
    n1, n2 = len(L), len(R)
    i, j = 0, 0
    k = l
    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
    if n1 < n2:
        len_i = n2
        list_i = R
        idx_i = j
    else:
        len_i = n1
        list_i = L
        idx_i = i
    while idx_i < len_i:
        arr[k] = list_i[idx_i]
        idx_i += 1
        k += 1


def msort(arr, l, r):
    if l < r:
        m = l + (r - l) // 2
        msort(arr, l, m)
        msort(arr, m + 1, r)
        merge(arr, l, m, r)


a = list(map(int, input().split()))
ans_arr = []
for i in range(len(a) - 1):
    t = a[i]
    p = 0
    for j in range(i + 1, len(a)):
        if(a[j] > t):
            t = a[j]
            p += 1
    ans_arr.append(p)
ans_arr.append(0)
print(" ".join(str(i) for i in ans_arr))
# Out:
# 4 4 3 3 2 1 0

# %%
# 5

# %%
# 6
# сотрировка по OX, потом сравниваем i и n - i элемент по
# противоположности по OX и совпадению по OY
#
# внимание - от полностью идентичных избавиться,
# они будут все ломать

def merge(arrx, arry, l, m, r):
    Lx = arrx[l : m + 1]
    Rx = arrx[m + 1 : r + 1]
    Ly = arry[l : m + 1]
    Ry = arry[m + 1 : r + 1]
    n1, n2 = len(Lx), len(Rx) # длины ix и iy должны быть равны
    i, j = 0, 0
    k = l
    while i < n1 and j < n2:
        if Lx[i] <= Rx[j]: # вот тут лишнее равно
            arrx[k] = Lx[i]
            arry[k] = Ly[i]
            i += 1
        else:
            arrx[k] = Rx[j]
            arry[k] = Ry[j]
            j += 1
        k += 1 # ВАЖНО - добавить: если X-ы равны, то по возрастанию игреков
    if n1 < n2:
        len_i = n2
        list_i = Rx
        idx_i = j
    else:
        len_i = n1
        list_i = Lx
        idx_i = i
    while idx_i < len_i:
        arrx[k] = list_i[idx_i]
        idx_i += 1
        k += 1


def msort(arrx, arry, l, r):
    if l < r:
        m = l + (r - l) // 2
        msort(arrx, arry, l, m)
        msort(arrx, arry, m + 1, r)
        merge(arrx, arry, l, m, r)


pts = int(input())
X, Y = [], []
for i in range(pts):
    t1, t2 = map(int, input().split())
    X.append(t1)
    Y.append(t2)
msort(X, Y, 0, pts - 1)


d1 = X[0]
for i in range(pts):
    X[i] = X[i] - d1


mid = X[pts - 1] / 2 # все верно, деление дробное
for i in range(pts):
    X[i] = X[i] - mid


mcheck = True
for i in range(pts // 2): # все верно, деление целое
    if not ((X[i] == (-1) * X[pts - 1 - i]) and (Y[i] == Y[pts - 1 - i])):
        mcheck = False
print(1 if mcheck == True else 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 51
#      49 X, Y = [], []
#      50 for i in range(pts):
# ---> 51     t1, t2 = map(int, input().split())
#      52     X.append(t1)
#      53     Y.append(t2)
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
# 6
# сотрировка по OX, потом сравниваем i и n - i элемент по
# противоположности по OX и совпадению по OY

def merge(arrx, arry, l, m, r):
    Lx = arrx[l : m + 1]
    Rx = arrx[m + 1 : r + 1]
    Ly = arry[l : m + 1]
    Ry = arry[m + 1 : r + 1]
    n1, n2 = len(Lx), len(Rx) # длины ix и iy должны быть равны
    i, j = 0, 0
    k = l
    while i < n1 and j < n2:
        if Lx[i] <= Rx[j]:
            arrx[k] = Lx[i]
            arry[k] = Ly[i]
            i += 1
        else:
            arrx[k] = Rx[j]
            arry[k] = Ry[j]
            j += 1
        k += 1 # ВАЖНО - добавить: если X-ы равны, то по возрастанию игреков
    if n1 < n2:
        len_i = n2
        list_i = Rx
        idx_i = j
    else:
        len_i = n1
        list_i = Lx
        idx_i = i
    while idx_i < len_i:
        arrx[k] = list_i[idx_i]
        idx_i += 1
        k += 1


def msort(arrx, arry, l, r):
    if l < r:
        m = l + (r - l) // 2
        msort(arrx, arry, l, m)
        msort(arrx, arry, m + 1, r)
        merge(arrx, arry, l, m, r)


pts = int(input())
X, Y = [], []
for i in range(pts):
    t1, t2 = map(int, input().split())
    X.append(t1)
    Y.append(t2)
msort(X, Y, 0, pts - 1)
i = 0
while(i < pts - 1):
    if (X[i] == X[i + 1]) and (Y[i] == Y[i + 1]):
        pts -= 1 # тут избавились от повторов
        X.pop(i)
        Y.pop(i)
    i += 1
print(pts)
d1 = X[0]
for i in range(pts):
    X[i] = X[i] - d1


mid = X[pts - 1] / 2 # все верно, деление дробное
for i in range(pts):
    X[i] = X[i] - mid


mcheck = True
for i in range(pts // 2): # все верно, деление целое
    if not ((X[i] == (-1) * X[pts - 1 - i]) and (Y[i] == Y[pts - 1 - i])):
        mcheck = False
print(1 if mcheck == True else 0)
print(X)
print(Y)

# проблема в игреках в сорте, пиздарики
# и не только в сорте, вообще пиздарики
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 48
#      46 X, Y = [], []
#      47 for i in range(pts):
# ---> 48     t1, t2 = map(int, input().split())
#      49     X.append(t1)
#      50     Y.append(t2)
#
# ValueError: invalid literal for int() with base 10: 'CATGAC'

# %%
# 4
# ниже - функция для растчета инверсий, работает
def inversions(string):
    t = 0
    for i in range(len(string) - 1):
        for j in range(i + 1, len(string)):
            if string[i] > string[j]:
                t += 1
    return t
# время переписывать мержсорт
def merge(arr1, arr2, l, m, r):
    L1 = arr[l : m + 1]
    R1 = arr[m + 1 : r + 1]
    L2 = arr[l : m + 1]
    R2 = arr[m + 1 : r + 1]
    n1, n2 = len(L), len(R)
    i, j = 0, 0
    k = l
    while i < n1 and j < n2:
        if inversions(L[i]) < inversions(R[j]):
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
    if n1 < n2:
        len_i = n2
        list_i = R
        idx_i = j
    else:
        len_i = n1
        list_i = L
        idx_i = i
    while idx_i < len_i:
        arr[k] = list_i[idx_i]
        idx_i += 1
        k += 1


def msort(arr, l, r):
    if l < r:
        m = l + (r - l) // 2
        msort(arr, l, m)
        msort(arr, m + 1, r)
        merge(arr, l, m, r)


def rolley(a): # на входе отсорченный массив !!!
    double_array = []
    for i in range(inversions(a[len(a) - 1]) + 1):
        double_array.append([])
        for j in a:
            if inversions(j) == i:
                double_array[i].append(j)
    for i in range(len(double_array)):
        double_array[i].reverse()
    t = []
    for i in range(len(double_array)):
        for j in double_array[i]:
            t.append(j)
    return t


testcount = int(input())
for i in range(testcount):
    strlen, strcount = map(int, input().split())
    a = []
    for i in range(strcount):
        a.append(input())
    msort(a, 0, strcount - 1)
    a = rolley(a)
    for i in range(strcount):
        print(a[i], end="")
        print("\n", end="")
    print("\n", end="")
# Out:
# acgt
# agct
# actg

# %%
# 5

# merge sort implementation
def merge(arr, l, m, r):
    L = arr[l : m + 1]
    R = arr[m + 1 : r + 1]
    n1, n2 = len(L), len(R)
    i, j = 0, 0
    k = l
    while i < n1 and j < n2:
        if len(L[i]) >= len(R[j]):
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
    if n1 < n2:
        len_i = n2
        list_i = R
        idx_i = j
    else:
        len_i = n1
        list_i = L
        idx_i = i
    while idx_i < len_i:
        arr[k] = list_i[idx_i]
        idx_i += 1
        k += 1


def msort(arr, l, r):
    if l < r:
        m = l + (r - l) // 2
        msort(arr, l, m)
        msort(arr, m + 1, r)
        merge(arr, l, m, r)


def same(werd1, werd2): # проверка на принадлежность к одной группе
    if len(werd1) >= len(werd2):
        mn = werd2
        mx = werd1
    else:
        mn = werd1
        mx = werd2
    salt = True
    for i in range(len(mx)):
        if not (mx[i] in mn):
            salt = False
    for i in range(len(mn)):
        if not (mn[i] in mx):
            salt = False
    return salt

def srt(a):
    for i in range(len(a) - 1):
        for j in range(i + 1, len(a)):
            if a[i] >= a[j]:
                a[i], a[j] = a[j], a[i]

w = list(input().split())
groups = [[0]] * 1
groups[0][0] = w[0]

for i in range(1, len(w)):
    salt = False
    for j in range(len(groups)):
        if same(w[i], groups[j][0]):
            groups[j].append(w[i])
            salt = True
    if not salt:
        groups.append([])
        groups[len(groups) - 1].append(w[i])
msort(groups, 0, len(groups) - 1)
for i in range(len(groups)):
    srt(groups[i])
#
p = -1
for i in range(len(groups)):
    if len(groups[i]) == 1:
        p = i
        break
temp = []
for i in range(p, len(groups)):
    temp.append(groups[i][0])
srt(temp)
#

for i in range(p):
    print(" ".join(str(groups[i][j]) for j in range(len(groups[i]))), end=" ")
print(" ".join(str(temp[i]) for i in range(len(temp))))
# Out:
# dachidlrss dachidlrss dachidlsrs dachidlsrs dachidlssr dachidlssr dachidrlss dachidrlss dachidslrs dachidslrs dachidslsr dachidslsr dachidsrls dachidsrls dachidsrsl dachidsrsl dachidsslr dachidsslr dachidssrl dachidssrl hapomacbnt hapomacbtn hapomacnbt hapomacntb hapomactbn hapomactnb hapomanctb hapomantbc hapomantcb hapomatbcn hapomatbnc hapomatcbn hapomatcnb hapomatnbc hapomatncb kpktspabnp kpktspabpn kpktspanbp kpktspanpb kpktspapbn kpktspapnb kpktsppabn kpktsppanb kpktsppban kpktsppbna ilhreogpdi ilhreogpid ilhreopdgi ilhreopdig ilhreopgdi ilhreopgid ilhreopidg ilhreopigd nfgbtambls nfgbtambsl nfgbtamlbs nfgbtamlsb nfgbtamsbl nfgbtamslb pfiampobnt pfiampobtn pfiamponbt pfiampontb irrlphndfs irrlphndsf aoeidellpi bisibcrled btcknchrdm drnokdanoh droffmogge drppcahcos dtsnmeltsm edhbibmdam ersmpsgedg fentnscdtt ffgmafrdpn fftpamfdll fofdsfnpfo fseboibhft gcglmogetm idbhioteco istkgifimg ksildntirn ksnsnpfogi lpaddhlnea m mcdanrosso mdtnlpdmdf mphihglmgs nbscriseib oanmdilmrc onkfbm
# ...

# %%
"""def stringmerge(arr, l, m, r):
    L = arr[l : m + 1]
    R = arr[m + 1 : r + 1]
    n1, n2 = len(L), len(R)
    i, j = 0, 0
    k = l
    while i < n1 and j < n2:
        if L[i] >= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
    if n1 < n2:
        len_i = n2
        list_i = R
        idx_i = j
    else:
        len_i = n1
        list_i = L
        idx_i = i
    while idx_i < len_i:
        arr[k] = list_i[idx_i]
        idx_i += 1
        k += 1


def stringmsort(arr, l, r):
    if l < r:
        m = l + (r - l) // 2
        msort(arr, l, m)
        msort(arr, m + 1, r)
        merge(arr, l, m, r)"""
def srt(a):
    for i in range(len(a) - 1):
        for j in range(i + 1, len(a)):
            if a[i] < a[j]:
                a[i], a[j] = a[j], a[i]

w = list(input().split())
#stringmsort(w, 0, len(w) - 1)
srt(w)
print(w)
# Out:
# ['cab', 'acc', 'abc', 'abb']

# %%
#6 еще раз
# merg
def merge(arr1, arr2, l, m, r):
    L1 = arr1[l : m + 1]
    R1 = arr1[m + 1 : r + 1]
    L2 = arr2[l : m + 1]
    R2 = arr2[m + 1 : r + 1]
    n1, n2 = len(L1), len(R1)
    i, j = 0, 0
    k = l
    while i < n1 and j < n2:
        if L1[i] <= R1[j]:
            arr1[k] = L1[i]
            arr2[k] = L2[i]
            i += 1
        else:
            arr1[k] = R1[j]
            arr2[k] = R2[j]
            j += 1
        k += 1
    if n1 < n2:
        len_i = n2
        list_i1 = R1
        list_i2 = R2
        idx_i = j
    else:
        len_i = n1
        list_i1 = L1
        list_i2 = L2
        idx_i = i
    while idx_i < len_i:
        arr1[k] = list_i1[idx_i]
        arr2[k] = list_i2[idx_i]
        idx_i += 1
        k += 1


def msort(arr1, arr2, l, r):
    if l < r:
        m = l + (r - l) // 2
        msort(arr1, arr2, l, m)
        msort(arr1, arr2, m + 1, r)
        merge(arr1, arr2, l, m, r)


listlen = int(input())
listx = []
listy = []
for i in range(listlen):
    t1, t2 = map(int, input().split())
    listx.append(t1)
    listy.append(t2)
msort(listx, listy, 0, listlen - 1) # вроде сортит

median = (listx[listlen - 1] + listx[0]) / 2
mid = (listx[listlen - 1] - listx[0]) / 2
listx1, listy1 = [], []
for i in range(listlen):
    if listx[i] != median:
        listx1.append(listx[i])
        listy1.append(listy[i])
salt = True

l = len(listx1)
for i in range(l//2):
    if not ((median - listx1[i] == listx1[l - 1 - i] - median) and (listy1[i] == listy1[l - 1 - i])):
        salt = False
print(1 if salt else 0)
# Out:
# 1
